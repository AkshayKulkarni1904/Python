# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshayKulkarni1904/Python/blob/main/notebooks/day_24_25_data_science_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path='/content/CO2 Emissions_Canada.csv'

# %%
import pandas as pd
c=pd.read_csv(path)

# %%
c['Make'].unique()
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
#        'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
#        'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'],
#       dtype=object)

# %%
c.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
#Display all unique fuel types
c["Fuel Type"].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %%
#Find the average CO2 emission of all vehicles
print(c['CO2 Emissions(g/km)'].mean())
# Out:
# 250.58469871360867

# %%
#For rounded output:
print(round(c['CO2 Emissions(g/km)'].mean(),2))
# Out:
# 250.58

# %%
#Find the vehicle with the highest CO2 emission
c.loc[c['CO2 Emissions(g/km)'].max()]
# Out:
# Make                                 HYUNDAI
# Model                               VELOSTER
# Vehicle Class                        COMPACT
# Engine Size(L)                           1.6
# Cylinders                                  4
# Transmission                             AM6
# Fuel Type                                  X
# Fuel Consumption City (L/100 km)         8.6
# Fuel Consumption Hwy (L/100 km)          6.6
# Fuel Consumption Comb (L/100 km)         7.7
# Fuel Consumption Comb (mpg)               37
# CO2 Emissions(g/km)                      177
# Name: 522, dtype: object

# %%
#Find the vehicle with the lowest CO2 emission
c.loc[c['CO2 Emissions(g/km)'].min()]
# Out:
# Make                                              BMW
# Model                               435i xDRIVE COUPE
# Vehicle Class                                 COMPACT
# Engine Size(L)                                    3.0
# Cylinders                                           6
# Transmission                                       A8
# Fuel Type                                           Z
# Fuel Consumption City (L/100 km)                 11.7
# Fuel Consumption Hwy (L/100 km)                   7.8
# Fuel Consumption Comb (L/100 km)                  9.9
# Fuel Consumption Comb (mpg)                        29
# CO2 Emissions(g/km)                               228
# Name: 96, dtype: object

# %%
#Find all vehicles having engine size greater than 4 litres
c.query("`Engine Size(L)`>4")
# Out:
#               Make         Model            Vehicle Class  Engine Size(L)  \
# 13    ASTON MARTIN           DB9              MINICOMPACT             5.9
# 14    ASTON MARTIN        RAPIDE               SUBCOMPACT             5.9
# 15    ASTON MARTIN    V8 VANTAGE               TWO-SEATER             4.7
# 16    ASTON MARTIN    V8 VANTAGE               TWO-SEATER             4.7
# 17    ASTON MARTIN  V8 VANTAGE S               TWO-SEATER             4.7
# ...            ...           ...                      ...             ...
# 7291   ROLLS-ROYCE   Phantom EWB                FULL-SIZE             6.7
# 7292   ROLLS-ROYCE        Wraith                 MID-SIZE             6.6
# 7348        TOYOTA   Sequoia 4WD           SUV - STANDARD             5.7
# 7356        TOYOTA        Tundra  PICKUP TRUCK - STANDARD             5.7
# 7357        TOYOTA    Tundra 4WD  PICKUP TRUCK - STANDARD             5.7
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
#find the total number:
len(c[c["Engine Size(L)"] > 4])
# Out:
# 1495

# %%
#Count the number of vehicles for each manufacturer
c['Make'].value_counts()
# Out:
# Make
# FORD             628
# CHEVROLET        588
# BMW              527
# MERCEDES-BENZ    419
# PORSCHE          376
# TOYOTA           330
# GMC              328
# AUDI             286
# NISSAN           259
# JEEP             251
# DODGE            246
# KIA              231
# HONDA            214
# HYUNDAI          210
# MINI             204
# VOLKSWAGEN       197
# MAZDA            180
# LEXUS            178
# JAGUAR           160
# CADILLAC         158
# SUBARU           140
# VOLVO            124
# INFINITI         108
# BUICK            103
# RAM               97
# LINCOLN           96
# MITSUBISHI        95
# CHRYSLER          88
# LAND ROVER        85
# FIAT              73
# ACURA             72
# MASERATI          61
# ROLLS-ROYCE       50
# ASTON MARTIN      47
# BENTLEY           46
# LAMBORGHINI       41
# ALFA ROMEO        30
# GENESIS           25
# SCION             22
# SMART              7
# BUGATTI            3
# SRT                2
# ...

# %%
#Find the average CO2 emission for each fuel type
c.groupby("Fuel Type")["CO2 Emissions(g/km)"].mean()
# Out:
# Fuel Type
# D    237.548571
# E    275.091892
# N    213.000000
# X    235.119329
# Z    266.043410
# Name: CO2 Emissions(g/km), dtype: float64

# %%
#Find the top 5 manufacturers with the highest average CO2 emission
c.groupby('Make')['CO2 Emissions(g/km)'].mean().sort_values(ascending=False).head()
# Out:
# Make
# BUGATTI        522.000000
# LAMBORGHINI    400.780488
# SRT            389.000000
# ROLLS-ROYCE    388.480000
# BENTLEY        362.934783
# Name: CO2 Emissions(g/km), dtype: float64

# %%
#Find all BMW vehicles with CO2 emissions greater than 300 g/km
c[(c['Make']=='BMW')&(c['CO2 Emissions(g/km)']>300)]
# Out:
#      Make         Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 112   BMW         760Li       FULL-SIZE             6.0         12
# 118   BMW            M5        MID-SIZE             4.4          8
# 119   BMW            M5        MID-SIZE             4.4          8
# 120   BMW            M6         COMPACT             4.4          8
# 121   BMW            M6         COMPACT             4.4          8
# ...   ...           ...             ...             ...        ...
# 6631  BMW  X5 xDrive50i  SUV - STANDARD             4.4          8
# 6632  BMW       X5 M50i  SUV - STANDARD             4.4          8
# 6634  BMW       X6 M50i  SUV - STANDARD             4.4          8
# 6636  BMW  X7 xDrive50i  SUV - STANDARD             4.4          8
# 6637  BMW       X7 M50i  SUV - STANDARD             4.4          8
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 112            A8         Z                              18.7
# ...

# %%
#Sort the dataset based on CO2 emissions from highest to lowest
c.sort_values(by='CO2 Emissions(g/km)',ascending=False)
# Out:
#              Make               Model Vehicle Class  Engine Size(L)  \
# 6640      BUGATTI              Chiron    TWO-SEATER             8.0
# 5575      BUGATTI              Chiron    TWO-SEATER             8.0
# 4509      BUGATTI              CHIRON    TWO-SEATER             8.0
# 7059  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# 6046  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# ...           ...                 ...           ...             ...
# 6949      HYUNDAI               IONIQ     FULL-SIZE             1.6
# 6950      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 5931      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 4900      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
# 3824      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 6640         16          AM7         Z                              26.8
# ...

# %%
#top 10
c.sort_values(by='CO2 Emissions(g/km)',ascending=False).head(10)
# Out:
#                Make               Model    Vehicle Class  Engine Size(L)  \
# 6640        BUGATTI              Chiron       TWO-SEATER             8.0
# 5575        BUGATTI              Chiron       TWO-SEATER             8.0
# 4509        BUGATTI              CHIRON       TWO-SEATER             8.0
# 7059    LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 6046    LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 349            FORD          E350 WAGON  VAN - PASSENGER             6.8
# 6045    LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
# 7058    LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
# 2971  MERCEDES-BENZ            AMG G 65   SUV - STANDARD             6.0
# 5126  MERCEDES-BENZ            AMG G 65   SUV - STANDARD             6.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 6640         16          AM7         Z                              26.8
# ...

# %%
#Find the correlation between engine size and CO2 emissions
c['Engine Size(L)'].corr(c['CO2 Emissions(g/km)'])
# Out:
# np.float64(0.8511446437900007)

# %%
#Create a second dataset
manufacturer_data = {
    "Make": [
        "ACURA",
        "AUDI",
        "BMW",
        "CHEVROLET",
        "FORD",
        "HONDA",
        "HYUNDAI",
        "MERCEDES-BENZ",
        "TOYOTA",
        "VOLKSWAGEN"
    ],

    "Country": [
        "Japan",
        "Germany",
        "Germany",
        "USA",
        "USA",
        "Japan",
        "South Korea",
        "Germany",
        "Japan",
        "Germany"
    ],

    "Company_Type": [
        "Luxury",
        "Luxury",
        "Luxury",
        "Mass Market",
        "Mass Market",
        "Mass Market",
        "Mass Market",
        "Luxury",
        "Mass Market",
        "Mass Market"
    ]
}

c2 = pd.DataFrame(manufacturer_data)

c2
# Out:
#             Make      Country Company_Type
# 0          ACURA        Japan       Luxury
# 1           AUDI      Germany       Luxury
# 2            BMW      Germany       Luxury
# 3      CHEVROLET          USA  Mass Market
# 4           FORD          USA  Mass Market
# 5          HONDA        Japan  Mass Market
# 6        HYUNDAI  South Korea  Mass Market
# 7  MERCEDES-BENZ      Germany       Luxury
# 8         TOYOTA        Japan  Mass Market
# 9     VOLKSWAGEN      Germany  Mass Market

# %%
c2.to_csv("Manufacturer_Data.csv")

# %%
#Display the shape of both datasets
print(c.shape)
print(c2.shape)
# Out:
# (7385, 12)
# (10, 3)

# %%
#Display columns of both datasets
print(c.columns)
print(c2.columns)
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')
# Index(['Make', 'Country', 'Company_Type'], dtype='object')

# %%
set(c.columns) & set(c2.columns)
# Out:
# {'Make'}

# %%
#Merge both datasets using inner join
merged_c=pd.merge(c,c2,on='Make',how='inner')
merged_c.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
#Merge both datasets using left join
left_c=pd.merge(c,c2,on='Make',how='left')
left_c.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
#Find vehicles manufactured in Germany
merged_c[merged_c['Country']=='Germany']
# Out:
#             Make                 Model Vehicle Class  Engine Size(L)  \
# 12          AUDI                    A4       COMPACT             2.0
# 13          AUDI            A4 QUATTRO       COMPACT             2.0
# 14          AUDI            A4 QUATTRO       COMPACT             2.0
# 15          AUDI  A5 CABRIOLET QUATTRO    SUBCOMPACT             2.0
# 16          AUDI            A5 QUATTRO    SUBCOMPACT             2.0
# ...          ...                   ...           ...             ...
# 3466  VOLKSWAGEN             Jetta GLI       COMPACT             2.0
# 3467  VOLKSWAGEN             Jetta GLI       COMPACT             2.0
# 3468  VOLKSWAGEN                Passat      MID-SIZE             2.0
# 3469  VOLKSWAGEN                Tiguan   SUV - SMALL             2.0
# 3470  VOLKSWAGEN        Tiguan 4MOTION   SUV - SMALL             2.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
#Find luxury vehicles with CO₂ emissions greater than 300
merged_c[(merged_c['Company_Type']=='Luxury')&(merged_c['CO2 Emissions(g/km)']>300)]
# Out:
#                Make                       Model   Vehicle Class  \
# 28             AUDI                         A8L       FULL-SIZE
# 35             AUDI                          Q7  SUV - STANDARD
# 37             AUDI                          R8      TWO-SEATER
# 38             AUDI                          R8      TWO-SEATER
# 39             AUDI                          R8      TWO-SEATER
# ...             ...                         ...             ...
# 3389  MERCEDES-BENZ              AMG GT R Coupe      TWO-SEATER
# 3391  MERCEDES-BENZ  AMG S 63 4MATIC+ Cabriolet      SUBCOMPACT
# 3393  MERCEDES-BENZ                    AMG S 65       FULL-SIZE
# 3401  MERCEDES-BENZ                       G 550  SUV - STANDARD
# 3403  MERCEDES-BENZ               Maybach S 650       FULL-SIZE
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 28               6.3         12          AS8         Z
# 35               3.0          6          AS8         Z
# ...

# %%
#Find average CO₂ emissions by country
merged_c.groupby('Country')['CO2 Emissions(g/km)'].mean()
# Out:
# Country
# Germany        254.071379
# Japan          212.451299
# South Korea    208.871429
# USA            262.612664
# Name: CO2 Emissions(g/km), dtype: float64

# %%
#Find the country with the highest average CO₂ emission
merged_c.groupby('Country')['CO2 Emissions(g/km)'].mean().sort_values(ascending=False).head(1)
# Out:
# Country
# USA    262.612664
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# #**Day 25**
# ###**Data Science - II**

# %%
c.shape
# Out:
# (7385, 12)

# %%
#rename / change column name (Interview question)
#c.rename({old_name:new_name})
c.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
c.rename(columns={'Engine Size(L)':'ESL'})
# Out:
#        Make        Model   Vehicle Class  ESL  Cylinders Transmission  \
# 0     ACURA          ILX         COMPACT  2.0          4          AS5
# 1     ACURA          ILX         COMPACT  2.4          4           M6
# 2     ACURA   ILX HYBRID         COMPACT  1.5          4          AV7
# 3     ACURA      MDX 4WD     SUV - SMALL  3.5          6          AS6
# 4     ACURA      RDX AWD     SUV - SMALL  3.5          6          AS6
# ...     ...          ...             ...  ...        ...          ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL  2.0          4          AS8
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL  2.0          4          AS8
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL  2.0          4          AS8
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD  2.0          4          AS8
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD  2.0          4          AS8
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 0            Z                               9.9
# ...

# %%
#using mapper
#(use axis = 1 to access column and 0 for row)
c.rename(mapper={'Engine Size(L)':'ESL'},axis=1)
# Out:
#        Make        Model   Vehicle Class  ESL  Cylinders Transmission  \
# 0     ACURA          ILX         COMPACT  2.0          4          AS5
# 1     ACURA          ILX         COMPACT  2.4          4           M6
# 2     ACURA   ILX HYBRID         COMPACT  1.5          4          AV7
# 3     ACURA      MDX 4WD     SUV - SMALL  3.5          6          AS6
# 4     ACURA      RDX AWD     SUV - SMALL  3.5          6          AS6
# ...     ...          ...             ...  ...        ...          ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL  2.0          4          AS8
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL  2.0          4          AS8
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL  2.0          4          AS8
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD  2.0          4          AS8
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD  2.0          4          AS8
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 0            Z                               9.9
# ...

# %%
#access multiple
c.rename(mapper={'Engine Size(L)':'ESL','Make':'Manufacturer'},axis=1)
# Out:
#      Manufacturer        Model   Vehicle Class  ESL  Cylinders Transmission  \
# 0           ACURA          ILX         COMPACT  2.0          4          AS5
# 1           ACURA          ILX         COMPACT  2.4          4           M6
# 2           ACURA   ILX HYBRID         COMPACT  1.5          4          AV7
# 3           ACURA      MDX 4WD     SUV - SMALL  3.5          6          AS6
# 4           ACURA      RDX AWD     SUV - SMALL  3.5          6          AS6
# ...           ...          ...             ...  ...        ...          ...
# 7380        VOLVO  XC40 T5 AWD     SUV - SMALL  2.0          4          AS8
# 7381        VOLVO  XC60 T5 AWD     SUV - SMALL  2.0          4          AS8
# 7382        VOLVO  XC60 T6 AWD     SUV - SMALL  2.0          4          AS8
# 7383        VOLVO  XC90 T5 AWD  SUV - STANDARD  2.0          4          AS8
# 7384        VOLVO  XC90 T6 AWD  SUV - STANDARD  2.0          4          AS8
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
c.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
#seprate columns with specific data type
c.select_dtypes(include='float')
# Out:
#        Make        Model   Vehicle Class Transmission Fuel Type
# 0     ACURA          ILX         COMPACT          AS5         Z
# 1     ACURA          ILX         COMPACT           M6         Z
# 2     ACURA   ILX HYBRID         COMPACT          AV7         Z
# 3     ACURA      MDX 4WD     SUV - SMALL          AS6         Z
# 4     ACURA      RDX AWD     SUV - SMALL          AS6         Z
# ...     ...          ...             ...          ...       ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL          AS8         Z
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL          AS8         Z
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL          AS8         Z
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD          AS8         Z
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD          AS8         Z
#
# [7385 rows x 5 columns]

# %%
#Get multiple data types
#method 1
c.select_dtypes(include=[float,int])
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
#method 2
c.select_dtypes(include='number')
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
cat_cols = ['Make', 'Model', 'Vehicle Class', 'Transmission', 'Fuel Type']

for col_name in cat_cols:
  print(col_name,':',c[col_name].nunique())
# Out:
# Make : 42
# Model : 2053
# Vehicle Class : 16
# Transmission : 27
# Fuel Type : 5

# %%
cat_cols = ['Make', 'Model', 'Vehicle Class', 'Transmission', 'Fuel Type']

for col_name in cat_cols:
  print(col_name,':',c[col_name].unique())
  print('='*30)
# Out:
# Make : ['ACURA' 'ALFA ROMEO' 'ASTON MARTIN' 'AUDI' 'BENTLEY' 'BMW' 'BUICK'
#  'CADILLAC' 'CHEVROLET' 'CHRYSLER' 'DODGE' 'FIAT' 'FORD' 'GMC' 'HONDA'
#  'HYUNDAI' 'INFINITI' 'JAGUAR' 'JEEP' 'KIA' 'LAMBORGHINI' 'LAND ROVER'
#  'LEXUS' 'LINCOLN' 'MASERATI' 'MAZDA' 'MERCEDES-BENZ' 'MINI' 'MITSUBISHI'
#  'NISSAN' 'PORSCHE' 'RAM' 'ROLLS-ROYCE' 'SCION' 'SMART' 'SRT' 'SUBARU'
#  'TOYOTA' 'VOLKSWAGEN' 'VOLVO' 'GENESIS' 'BUGATTI']
# ...
# Model : ['ILX' 'ILX HYBRID' 'MDX 4WD' ... 'Tacoma 4WD D-Cab TRD Off-Road/Pro'
#  'Atlas Cross Sport 4MOTION' 'XC40 T4 AWD']
# ...
# Vehicle Class : ['COMPACT' 'SUV - SMALL' 'MID-SIZE' 'TWO-SEATER' 'MINICOMPACT'
#  'SUBCOMPACT' 'FULL-SIZE' 'STATION WAGON - SMALL' 'SUV - STANDARD'
#  'VAN - CARGO' 'VAN - PASSENGER' 'PICKUP TRUCK - STANDARD' 'MINIVAN'
#  'SPECIAL PURPOSE VEHICLE' 'STATION WAGON - MID-SIZE'
#  'PICKUP TRUCK - SMALL']
# ...
# Transmission : ['AS5' 'M6' 'AV7' 'AS6' 'AM6' 'A6' 'AM7' 'AV8' 'AS8' 'A7' 'A8' 'M7' 'A4'
# ...

# %%
cat_cols = ['Make', 'Model', 'Vehicle Class', 'Transmission', 'Fuel Type']

for col_name in cat_cols:
  print(col_name,':',c[col_name].value_counts())
  print('='*30)
# Out:
# Make : Make
# FORD             628
# CHEVROLET        588
# BMW              527
# MERCEDES-BENZ    419
# PORSCHE          376
# TOYOTA           330
# GMC              328
# AUDI             286
# NISSAN           259
# JEEP             251
# DODGE            246
# KIA              231
# HONDA            214
# HYUNDAI          210
# MINI             204
# VOLKSWAGEN       197
# MAZDA            180
# LEXUS            178
# JAGUAR           160
# CADILLAC         158
# SUBARU           140
# VOLVO            124
# INFINITI         108
# BUICK            103
# RAM               97
# LINCOLN           96
# MITSUBISHI        95
# CHRYSLER          88
# LAND ROVER        85
# FIAT              73
# ACURA             72
# MASERATI          61
# ROLLS-ROYCE       50
# ASTON MARTIN      47
# BENTLEY           46
# LAMBORGHINI       41
# ALFA ROMEO        30
# GENESIS           25
# SCION             22
# SMART              7
# BUGATTI            3
# SRT                2
# ...

# %%
#sort the records
c[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
c.describe().T
# Out:
#                                    count        mean        std   min    25%  \
# Engine Size(L)                    7385.0    3.160068   1.354170   0.9    2.0
# Cylinders                         7385.0    5.615030   1.828307   3.0    4.0
# Fuel Consumption City (L/100 km)  7385.0   12.556534   3.500274   4.2   10.1
# Fuel Consumption Hwy (L/100 km)   7385.0    9.041706   2.224456   4.0    7.5
# Fuel Consumption Comb (L/100 km)  7385.0   10.975071   2.892506   4.1    8.9
# Fuel Consumption Comb (mpg)       7385.0   27.481652   7.231879  11.0   22.0
# CO2 Emissions(g/km)               7385.0  250.584699  58.512679  96.0  208.0
#
#                                     50%    75%    max
# Engine Size(L)                      3.0    3.7    8.4
# Cylinders                           6.0    6.0   16.0
# Fuel Consumption City (L/100 km)   12.1   14.6   30.6
# Fuel Consumption Hwy (L/100 km)     8.7   10.2   20.6
# Fuel Consumption Comb (L/100 km)   10.6   12.6   26.1
# ...

# %%
#sort the value on the basis of column name and axis
#for coloumn axis should be 0 or index
#fow row axis should be 1 or 'column'
c.sort_values(by=['CO2 Emissions(g/km)'],axis='index')
# Out:
#              Make               Model Vehicle Class  Engine Size(L)  \
# 3824      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
# 6950      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 4900      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
# 5931      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 6949      HYUNDAI               IONIQ     FULL-SIZE             1.6
# ...           ...                 ...           ...             ...
# 7059  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# 6046  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# 5575      BUGATTI              Chiron    TWO-SEATER             8.0
# 4509      BUGATTI              CHIRON    TWO-SEATER             8.0
# 6640      BUGATTI              Chiron    TWO-SEATER             8.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 3824          4          AM6         X                               4.2
# ...
